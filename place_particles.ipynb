# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 11 16:39:06 2022

@author: ruijsch
"""

#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 11 16:39:06 2022

@author: ruijsch
"""

from parcels import FieldSet, ParticleSet, Variable, JITParticle, AdvectionRK4, plotTrajectoriesFile, ErrorCode, ParticleFile, ScipyParticle
from parcels import UnitConverter, Field, Variable
import numpy as np
import math
from datetime import timedelta, datetime
from datetime import timedelta as delta
from operator import attrgetter
from glob import glob
import copy
import xarray as xr
import matplotlib.pyplot as plt

import pandas as pd
from datetime import date, timedelta

#%%
#Load the data from Lorenz and define the indices
 
data_path_ocean = '/storage/shared/oceanparcels/input_data/MOi/'
# Load only a few time steps of the model output, to speed up this test simulation
ufiles = sorted(glob(data_path_ocean+'psy4v3r1/psy4v3r1-daily_U_*.nc'))[-1345:-980]
vfiles = [f.replace('_U_', '_V_') for f in ufiles]
wfiles = [f.replace('_U_', '_W_') for f in ufiles][:4]
mesh_mask = data_path_ocean + 'domain_ORCA0083-N006/coordinates.nc'

filenames = {'U': {'lon': mesh_mask, 'lat': mesh_mask, 'depth': wfiles[0], 'data': ufiles},
             'V': {'lon': mesh_mask, 'lat': mesh_mask, 'depth': wfiles[0], 'data': vfiles},

             }
variables = {'U': 'vozocrtx', 'V': 'vomecrty'}
dimensions = {'U': {'lon': 'glamf', 'lat': 'gphif', 'depth': 'depthw', 'time': 'time_counter'},
              'V': {'lon': 'glamf', 'lat': 'gphif', 'depth': 'depthw', 'time': 'time_counter'}}

# Madagascar indices
indices = {'lon': np.arange(3500,4321).tolist(),
            'lat': np.arange(900, 1600).tolist()}

#%%

data_path_wind = '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/'
# Load only a few time steps of the model output, to speed up this test simulation
wind_files = sorted(glob(data_path_wind+'ERA5_global_wind_monthly_*.nc'))[288:]

# the mesh mask comes from the ocean data path
mesh_mask = data_path_ocean + 'domain_ORCA0083-N006/coordinates.nc'


#%%

data_path_bathymetry = '/storage/shared/oceanparcels/input_data/MOi/'

maskfiles = data_path_bathymetry+'domain_ORCA0083-N006/bathymetry_ORCA12_V3.3.nc'

filenames_mask = {'mask': {'lon': maskfiles, 'lat': maskfiles, 'data': maskfiles}}

variables_mask = {'mask': 'mask'}
dimensions_mask = {'mask': {'lon': 'nav_lon', 'lat': 'nav_lat'}}

# Madagascar indices
indices_mask = {'lon': np.arange(3500,4321).tolist(),
            'lat': np.arange(900, 1600).tolist()}


#%%



coastfiles = 'distance_to_coast_22_04_22.nc'

filenames_coast = {'distance': {'lon': coastfiles, 'lat': coastfiles, 'data': coastfiles}}

variables_coast = {'distance': 'distance'}
dimensions_coast = {'distance': {'lon': 'lon', 'lat': 'lat'}}

# Madagascar indices -> it already has the right indices
# indices_coast = {'lon': np.arange(3500,4321).tolist(),
#             'lat': np.arange(900, 1600).tolist()}


boxfiles = 'box.nc'

filenames_coast = {'distance': {'lon': coastfiles, 'lat': coastfiles, 'data': coastfiles}}

variables_coast = {'distance': 'distance'}
dimensions_coast = {'distance': {'lon': 'lon', 'lat': 'lat'}}

# %%
wind_files
# Out:
# ['/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-01-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-02-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-03-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-04-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-05-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-06-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-07-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-08-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-09-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-10-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-11-01.nc',
#  '/storage/shared/oceanparcels/output_data/data_Mikael/ERA5/wind/ERA5_global_wind_monthly_converted_2019-12-01.nc']

# %%
ufiles
# Out:
# ['/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-01-31.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-02-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-03-31.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-04-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-05-31.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-06-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-07-31.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-08-31.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-09-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-10-31.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-11-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-01.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-02.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-03.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-04.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-05.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-06.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-07.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-08.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-09.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-10.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-11.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-12.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-13.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-14.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-15.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-16.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-17.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-18.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-19.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-20.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-21.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-22.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-23.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-24.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-25.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-26.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-27.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-28.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-29.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-30.nc',
#  '/storage/shared/oceanparcels/input_data/MOi/psy4v3r1/psy4v3r1-daily_U_2019-12-31.nc']

# %%
#%%
#Make the fieldsets for the currents, wind, land/sea mask and the coast

# note the indices argument and the 'allow time extrapolation=True' to speed up simulation
fset_currents = FieldSet.from_nemo(filenames, variables, dimensions, indices=indices) #, allow_time_extrapolation=True)


#%%

#withwind = 0.03  # wind factor of 3%
withwind = 0.03  # wind factor of 0%
if withwind:
    windfiles = {'U': wind_files,
                 'V': wind_files}
    winddimensions = {'lon': 'lon', 
                      'lat': 'lat', 
                      'time': 'time'}
    windvariables = {'U': 'u10', 'V': 'v10'}
    # Madagascar indices
    indices_wind = {'lon': np.arange(750, 1000).tolist(),
               'lat': np.arange(200, 400).tolist()}
    fset_wind = FieldSet.from_nemo(windfiles, windvariables, winddimensions,indices=indices_wind)#, allow_time_extrapolation=True)
    fset_wind.U.set_scaling_factor(withwind)
    fset_wind.V.set_scaling_factor(withwind)
    

#%%


fset_mask = FieldSet.from_nemo(filenames_mask, variables_mask, dimensions_mask, indices=indices_mask)
fset_coast = FieldSet.from_nemo(filenames_coast, variables_coast, dimensions_coast)

#%%

if withwind:
    fieldset = FieldSet(U=fset_currents.U + fset_wind.U, V=fset_currents.V + fset_wind.V)
else:
    fieldset = FieldSet(U=fset_currents.U, V=fset_currents.V)
    
fieldset.add_field(fset_mask.mask)
fieldset.add_field(fset_coast.distance)



day = 86400

#%%
#Custom particles and kernels

####################
# Custom Particles #
####################

class oceancc_particle(JITParticle):
    # add age of particle
    age = Variable('age', dtype=np.int32, initial=0.)
    stuck = Variable('stuck', dtype=np.int32, initial=0.)
    prev_lon = Variable('prev_lon', dtype=np.float32, to_write=False,
                        initial=attrgetter('lon'))  # the previous longitude
    prev_lat = Variable('prev_lat', dtype=np.float32, to_write=False,
                        initial=attrgetter('lat'))  # the previous latitude.
    first_lon = Variable('first_lon', dtype=np.float32, to_write=False,
                        initial=attrgetter('lon'))  # the initial longitude
    first_lat = Variable('first_lat', dtype=np.float32, to_write=False,
                        initial=attrgetter('lat'))  # the initial latitude.
    
    
fieldset.mask.data[:,:,650:] = 0
fieldset.mask.data[:,:,:220] = 0
fieldset.mask.data[:,:165,:] = 0
fieldset.mask.data[:,590:,:] = 0

X,Y = np.meshgrid(fieldset.mask.lon, fieldset.mask.lat)
p = fieldset.mask.data == 1
box_lon = X[p[0,:,:]]
box_lat = Y[p[0,:,:]]

# res = 0.01 #resolution in degrees

# minlon = 30
# maxlon = 58
# minlat = -33
# maxlat = -2
# grid = np.mgrid[int(minlon):int(maxlon):res,int(minlat):int(maxlat):res]+0.5

# n=grid[0].size

# lons_present = np.reshape(grid[0],n)
# lats_present = np.reshape(grid[1],n)

# Land = fieldset.mask
# dd = 1

# [lons_present,lats_present]=[np.array([lo for lo, la in zip(lons_present,lats_present) if Land[0,0,la,lo]==dd  ]),np.array([la for lo, la in zip(lons_present,lats_present) if Land[0,0,la,lo]==dd ])]

# np.save('lons_001_present.npy',(lons_present))
# np.save('lats_001_present.npy',(lats_present))

lonss = np.load('lons_001_present.npy')
latss = np.load('lats_001_present.npy')
depths = np.ones(np.shape(lonss)[0])*0.5
# Out:
# /nethome/6142060/parcels/parcels/field.py:248: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   timeslices = np.array(timeslices)
# /nethome/6142060/parcels/parcels/field.py:250: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   dataFiles = np.concatenate(np.array(dataFiles))

# %%
#%%
####################
# Particle Kernels #
####################

def DeleteParticle(particle, fieldset, time):
    particle.delete()

def PrintLoc(particle, fieldset, time):
    print('(lon, lat): (%.4f, %.4f)'%(particle.lon, particle.lat))
    
# Delete particles out of bounds
def deleteParticle(particle, fieldset, time):
    particle.delete()

# Particle ageing kernel
def ageingParticle(particle, fieldset, time): #age of the particle (in dt = 60 min) 
    particle.age += 1 #so age 1 = 60 minutes ( = dt)
    
def stuckParticle(particle, fieldset, time):
    if (particle.prev_lon == particle.lon) and (particle.prev_lat == particle.lat):
        particle.stuck += 1
    # Set the stored values for next iteration.
    particle.prev_lon = particle.lon
    particle.prev_lat = particle.lat

# Delete old particles
def killSwitch(particle, fieldset, time):
    if particle.age >= 24*30: #if particle is older than 30 days
        particle.delete() #delete it


def initloc(particle, fieldset, time):
    if time == 0:
        particle.first_lon = particle.lon
        particle.first_lat = particle.lat

# Delete old particles
# by repositioning them to their initial location
def killSwitch2(particle, fieldset, time):
    if particle.age >= 24*30:
        particle.lon = particle.first_lon
        particle.lat = particle.first_lat
        particle.age = 0
        particle.stuck = 0


def AdvectionRK4_Land(particle, fieldset, time):  
    if fieldset.mask[particle] == 0: #or fieldset.distance[particle] < 10:
    #if fieldset.distance[particle] <= 10:
        #land
        particle.lon = particle.prev_lon
        particle.lat = particle.prev_lat 
        
            
    if fieldset.mask[particle] == 1: # and fieldset.distance[particle] > 10:
    #if fieldset.distance[particle] > 10:
        #ocean
        (u1, v1) = fieldset.UV[particle]
        lon1, lat1 = (particle.lon + u1*.5*particle.dt, particle.lat + v1*.5*particle.dt)
        (u2, v2) = fieldset.UV[time + .5 * particle.dt, particle.depth, lat1, lon1, particle]
        lon2, lat2 = (particle.lon + u2*.5*particle.dt, particle.lat + v2*.5*particle.dt)
        (u3, v3) = fieldset.UV[time + .5 * particle.dt, particle.depth, lat2, lon2, particle]
        lon3, lat3 = (particle.lon + u3*particle.dt, particle.lat + v3*particle.dt)
        (u4, v4) = fieldset.UV[time + particle.dt, particle.depth, lat3, lon3, particle]
        particle.lon += (u1 + 2*u2 + 2*u3 + u4) / 6. * particle.dt
        particle.lat += (v1 + 2*v2 + 2*v3 + v4) / 6. * particle.dt

# %%
print('done')
# Out:
# done

# %%
fieldset.U[0].show()
# Out:
# /opt/apps/miniconda3/envs/parcels-dev/lib/python3.8/site-packages/matplotlib/colors.py:1201: RuntimeWarning: invalid value encountered in subtract
#   resdat -= vmin
# /opt/apps/miniconda3/envs/parcels-dev/lib/python3.8/site-packages/matplotlib/colors.py:620: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N

# %%
fieldset.U[1].show()

# %%
fieldset.U[1].show()

# %%
#days = np.array([5]) 
#days = [360,365]

day = 5
pset = ParticleSet.from_list(fieldset=fieldset, pclass=oceancc_particle, lon=lonss, lat=latss, depth = depths, time = 60*60*24*day)

# %%
pset.show(field=fieldset.U[0])

# %%
pset.show(field=fieldset.U[1])

# %%
pset.show(field=fieldset.U[1])

# %%
kernels = pset.Kernel(ageingParticle) + pset.Kernel(killSwitch) + pset.Kernel(stuckParticle) +  pset.Kernel(AdvectionRK4_Land)

output_file = pset.ParticleFile(name='2022_11_02_present_day_test'+str(day)+'.nc', 
                         outputdt=timedelta(hours=3))#, convert_at_end=True)


pset.execute(pyfunc=kernels, output_file=output_file, runtime=timedelta(days=5), dt=timedelta(minutes=60), verbose_progress=True, recovery={ErrorCode.ErrorOutOfBounds: DeleteParticle})

output_file.close()

print('done')
